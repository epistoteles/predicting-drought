# %% [markdown]
# # Predicting Droughts with Meteorological Data
# ## Machine Learning Project Submission
# ### _Korbinian Koch_ (korbinian.koch@uni-hamburg.de)

# %% [markdown]
# ## Loading the training data
# In this section, we load the training and validation data into numpy arrays.

# %%
import sys
# !{sys.executable} -m pip install numpy pandas sktime sklearn scipy seaborn matplotlib

# expand notebook width to see details in wider plots, feel free to adjust
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:65% !important;}</style>"))
# Out:
# ...
# <style>.container { width:65% !important;}</style>

# %% [markdown]
# We load the csv file paths for training, validation and testing into the ``files`` dictionary.

# %%
import numpy as np
import pandas as pd
import json
import os
import matplotlib.pyplot as plt
import seaborn as sns
import time
from tqdm.auto import tqdm
from datetime import datetime
from scipy.interpolate import interp1d
from sklearn.preprocessing import RobustScaler
sns.set_style('white')

files = {}

for dirname, _, filenames in os.walk('.'):
    for filename in filenames:
        if 'train' in filename:
            files['train'] = os.path.join(dirname, filename)
        if 'valid' in filename:
            files['valid'] = os.path.join(dirname, filename)
        if 'test' in filename:
            files['test'] = os.path.join(dirname, filename)
            
print(files)
# Out:
# {'test': './test_timeseries.csv', 'train': './train_timeseries.csv', 'valid': './validation_timeseries.csv'}

# %% [markdown]
# The following classes exist, ranging from no drought (``None``), to extreme drought (``D4``).
# This could be treated as a regression, ordinal or classification problem, but for now we will treat it as 5 distinct classes.

# %%
class2id = {
    'None': 0,
    'D0': 1,
    'D1': 2,
    'D2': 3,
    'D3': 4,
    'D4': 5,
}
id2class = {v: k for k, v in class2id.items()}

# %%
index2feature = {
    0: 'PRECTOT',
    1: 'PS',
    2: 'QV2M',
    3: 'T2M',
    4: 'T2MDEW',
    5: 'T2MWET',
    6: 'T2M_MAX',
    7: 'T2M_MIN',
    8: 'T2M_RANGE',
    9: 'TS',
    10: 'WS10M',
    11: 'WS10M_MAX',
    12: 'WS10M_MIN',
    13: 'WS10M_RANGE',
    14: 'WS50M',
    15: 'WS50M_MAX',
    16: 'WS50M_MIN',
    17: 'WS50M_RANGE',
    18: 'SCORE',
    19: 'DATE_SIN',
    20: 'DATE_COS'
}
feature2index = {v: k for k, v in index2feature.items()}

# %% [markdown]
# Now we'll define a helper method to load the datasets. This just walks through the json and discards the few samples that are corrupted.

# %%
dfs = {
    k: pd.read_csv(files[k]).set_index(['fips', 'date'])
    for k in files.keys()
}

# %% [markdown]
# The following are the first 60 days of the first county (1001). As you can see, drought data (last column ``score``) is only provided for on a weekly basis. It will be filled in by our interpolation function defined further below.

# %%
dfs['train'].head(90)
# Out:
#                  PRECTOT      PS   QV2M    T2M  T2MDEW  T2MWET  T2M_MAX  \
# fips date
# 1001 2000-01-01     0.22  100.51   9.65  14.74   13.51   13.51    20.96
#      2000-01-02     0.20  100.55  10.42  16.69   14.71   14.71    22.80
#      2000-01-03     3.65  100.15  11.76  18.49   16.52   16.52    22.73
#      2000-01-04    15.95  100.29   6.42  11.40    6.09    6.10    18.09
#      2000-01-05     0.00  101.15   2.95   3.86   -3.29   -3.20    10.82
# ...                  ...     ...    ...    ...     ...     ...      ...
#      2000-03-26     2.92   99.85  10.45  17.14   14.63   14.63    22.80
#      2000-03-27     4.08   98.90   8.91  14.53   11.78   11.78    22.22
#      2000-03-28     0.00   99.07   7.46  14.58    9.10    9.10    24.09
#      2000-03-29     1.77   99.65   8.12  14.82   10.34   10.35    21.28
#      2000-03-30     7.52   99.52  11.90  19.60   16.55   16.54    26.70
#
#                  T2M_MIN  T2M_RANGE     TS  WS10M  WS10M_MAX  WS10M_MIN  \
# fips date
# ...

# %%
def interpolate_nans(padata, pkind='linear'):
    """
    see: https://stackoverflow.com/a/53050216/2167159
    """
    aindexes = np.arange(padata.shape[0])
    agood_indexes, = np.where(np.isfinite(padata))
    f = interp1d(agood_indexes
               , padata[agood_indexes]
               , bounds_error=False
               , copy=False
               , fill_value="extrapolate"
               , kind=pkind)
    return f(aindexes)

# %% [markdown]
# We encode the day of year using sin/cos and add the data loading function `loadXY`.

# %%
def date_encode(date):
    if isinstance(date, str):
        date = datetime.strptime(date, "%Y-%m-%d")
    return (
        np.sin(2 * np.pi * date.timetuple().tm_yday / 366),
        np.cos(2 * np.pi * date.timetuple().tm_yday / 366)
    )

def loadXY(
    df,
    random_state=42, # keep this at 42
    window_size=180, # how many days in the past (default/competition: 180)
    target_size=6, # how many weeks into the future (default/competition: 6)
    fuse_past=True, # add the past drought observations? (default: True)
    return_fips=False, # return the county identifier (do not use for predictions)
    encode_season=True, # encode the season using the function above (default: True) 
    use_prev_year=False, # add observations from 1 year prior?
):
    df = dfs[df]
    soil_df = pd.read_csv("soil_data.csv")
    time_data_cols = sorted(
        [c for c in df.columns if c not in ["fips", "date", "score"]]
    )
    static_data_cols = sorted(
        [c for c in soil_df.columns if c not in ["soil", "lat", "lon"]]
    )
    count = 0
    score_df = df.dropna(subset=["score"])
    X_static = np.empty((len(df) // window_size, len(static_data_cols)))
    X_fips_date = []
    add_dim = 0
    if use_prev_year:
        add_dim += len(time_data_cols)
    if fuse_past:
        add_dim += 1
        if use_prev_year:
            add_dim += 1
    if encode_season:
        add_dim += 2
    X_time = np.empty(
        (len(df) // window_size, window_size, len(time_data_cols) + add_dim)
    )
    y_past = np.empty((len(df) // window_size, window_size))
    y_target = np.empty((len(df) // window_size, target_size))
    if random_state is not None:
        np.random.seed(random_state)
    for fips in tqdm(score_df.index.get_level_values(0).unique()):
        if random_state is not None:
            start_i = np.random.randint(1, window_size)
        else:
            start_i = 1
        fips_df = df[(df.index.get_level_values(0) == fips)]
        X = fips_df[time_data_cols].values
        y = fips_df["score"].values
        X_s = soil_df[soil_df["fips"] == fips][static_data_cols].values[0]
        for i in range(start_i, len(y) - (window_size + target_size * 7), window_size):
            X_fips_date.append((fips, fips_df.index[i : i + window_size][-1]))
            X_time[count, :, : len(time_data_cols)] = X[i : i + window_size]
            if use_prev_year:
                if i < 365 or len(X[i - 365 : i + window_size - 365]) < window_size:
                    continue
                X_time[count, :, -len(time_data_cols) :] = X[
                    i - 365 : i + window_size - 365
                ]
            if not fuse_past:
                y_past[count] = interpolate_nans(y[i : i + window_size])
            else:
                X_time[count, :, len(time_data_cols)] = interpolate_nans(
                    y[i : i + window_size]
                )
            if encode_season:
                enc_dates = [
                    date_encode(d) for f, d in fips_df.index[i : i + window_size].values
                ]
                d_sin, d_cos = [s for s, c in enc_dates], [c for s, c in enc_dates]
                X_time[count, :, len(time_data_cols) + (add_dim - 2)] = d_sin
                X_time[count, :, len(time_data_cols) + (add_dim - 2) + 1] = d_cos
            temp_y = y[i + window_size : i + window_size + target_size * 7]
            y_target[count] = np.array(temp_y[~np.isnan(temp_y)][:target_size])
            X_static[count] = X_s
            count += 1
    print(f"loaded {count} samples")
    results = [X_static[:count], X_time[:count], y_target[:count]]
    if not fuse_past:
        results.append(y_past[:count])
    if return_fips:
        results.append(X_fips_date)
    return results

# %% [markdown]
# Now we add a helper to normalise the data.

# %%
scaler_dict = {}
scaler_dict_static = {}
scaler_dict_past = {}


def normalize(X_static, X_time, y_past=None, fit=False):
    for index in tqdm(range(X_time.shape[-1])):
        if fit:
            scaler_dict[index] = RobustScaler().fit(X_time[:, :, index].reshape(-1, 1))
        X_time[:, :, index] = (
            scaler_dict[index]
            .transform(X_time[:, :, index].reshape(-1, 1))
            .reshape(-1, X_time.shape[-2])
        )
    for index in tqdm(range(X_static.shape[-1])):
        if fit:
            scaler_dict_static[index] = RobustScaler().fit(
                X_static[:, index].reshape(-1, 1)
            )
        X_static[:, index] = (
            scaler_dict_static[index]
            .transform(X_static[:, index].reshape(-1, 1))
            .reshape(1, -1)
        )
    index = 0
    if y_past is not None:
        if fit:
            scaler_dict_past[index] = RobustScaler().fit(y_past.reshape(-1, 1))
        y_past[:, :] = (
            scaler_dict_past[index]
            .transform(y_past.reshape(-1, 1))
            .reshape(-1, y_past.shape[-1])
        )
        return X_static, X_time, y_past
    return X_static, X_time

# %% [markdown]
# We can now load our training data set, where X consists of static (soil) and time (meteorological) data and Y consists of the future drought values.

# %%
X_static_train, X_time_train, y_target_train = loadXY("train")
print("train shape", X_time_train.shape)
X_static_train, X_time_train = normalize(X_static_train, X_time_train, fit=True)
# Out:
#   0%|          | 0/3108 [00:00<?, ?it/s]
# loaded 103390 samples
# train shape (103390, 180, 21)
# ...
#   0%|          | 0/30 [00:00<?, ?it/s]

# %%
print('First line of above data frame:')
print(X_time_train[0][0])
print('...')
print('Last line of above data frame:')
print(X_time_train[0][-1])
print()
print('Labels to be predicted:')
print(y_target_train[0])
# Out:
# First line of above data frame:
# [ 3.55963303  0.51213592  0.48289474  0.13654618  0.43567961  0.43613139
#  -0.00455322  0.28113879 -0.65371025  0.1338227  -0.53252033 -0.48484848
#  -0.2345679  -0.48148148 -0.44155844 -0.43501326 -0.2        -0.29166667
#   0.8301314   0.67585565 -0.13296077]
# ...
# Last line of above data frame:
# [-0.08256881  0.75       -0.5        -0.26965003 -0.63046117 -0.62347932
#  -0.20830962 -0.25563464  0.31272085 -0.25239977 -0.07723577 -0.20936639
#   0.09876543 -0.29218107  0.16883117 -0.18567639  0.61355932 -0.84469697
#   3.91880129 -0.70869533  0.12156313]
#
# Labels to be predicted:
# [4.7206 5.     5.     5.     4.     4.    ]

# %% [markdown]
# To create ``X_train``, we are flattening out the time data, pretending there is no temporal component. Then we are concatenating the static soil data.

# %%
print(X_time_train.shape)
X_train = np.array(list(map(lambda x: x.flatten(), X_time_train)))
print(X_train.shape)
print(X_static_train.shape)
X_train = np.concatenate((X_train, X_static_train), axis=1)
print(X_train.shape)
# Out:
# (103390, 180, 21)
# (103390, 3780)
# (103390, 30)
# (103390, 3810)

# %% [markdown]
# ## Visualization and reporting functions
#
# Here, we define some functions for calculating F1-scores as well as printing a beautiful confusion matrices.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import metrics
import re
import warnings

# %% [markdown]
# ``round_and_intify()`` rounds interpolated drought values like 1.21 into clean integers between 0 and 5.

# %%
def round_and_intify(y):
    return np.clip(np.squeeze(y).round().astype('int'), 0, 5)

# %% [markdown]
# ``bold()`` surrounds a string in **boldness** modifiers for printing

# %%
def bold(string):
    return f'\033[1m{string}\033[0m'

# %% [markdown]
# ``plot_confusion_matrix()`` plots a single seaborn confusion matrix

# %%
def plot_confusion_matrix(matrix, labels):
    plt.figure(1, figsize=(8.7, 7))
    ax = sns.heatmap(matrix, annot=True, cmap="YlGnBu", vmin=0, vmax=1)
    ax.set_xticklabels(labels)
    ax.xaxis.tick_top()
    ax.xaxis.set_label_position('top') 
    ax.tick_params(axis='both', which='both', length=0)
    ax.set_yticklabels(labels, rotation=90, va="center")
    ax.set_xlabel("Predicted Label", labelpad=18, fontdict=dict(weight='bold'))
    ax.set_ylabel("True Label", labelpad=15, fontdict=dict(weight='bold'))
    colorax = plt.gcf().axes[-1]
    colorax.tick_params(length=0)
    plt.show()

# %% [markdown]
# ``plot_confusion_matrices()`` plots a series of six seaborn confusion matrices

# %%
def plot_confusion_matrices(matrices, labels, macro_f1s, maes):
    fig, axes = plt.subplots(1, 6, sharex=True, sharey=True, figsize=(20,5.6))
    for i, (matrix, macro_f1, mae) in enumerate(zip(matrices, macro_f1s, maes)):
        sns.heatmap(matrix, ax=axes[i], annot=True, cmap="YlGnBu", vmin=0, vmax=1, cbar=False)
        axes[i].set_xticklabels(labels)
        axes[i].xaxis.tick_top()
        axes[i].xaxis.set_label_position('top') 
        axes[i].tick_params(axis='both', which='both', length=0)
        axes[i].set_yticklabels(labels, rotation=90, va="center")
        axes[i].text(3, 7,f'MAE: {mae}\nMacro F1: {macro_f1}', fontsize=14, ha='center')
        axes[i].set_xlabel(f"Predicted Label\nWeek {i+1}", labelpad=15, fontdict=dict(weight='bold'), fontsize=14)
        axes[0].set_ylabel("True Label", labelpad=12, fontdict=dict(weight='bold'), fontsize=14)
    fig.suptitle(f'avg. MAE: {np.mean([float(x) for x in maes]):.3f}\n' \
                 f'avg. Macro F1: {np.mean([float(x) for x in macro_f1s]):.3f}', 
                 fontsize=14,
                 fontweight='bold',
                 y=0.02)
    fig.tight_layout()
    plt.show()

# %% [markdown]
# ``summarize()`` prints a series of confusion matrices from (rounded) true and predicted y values

# %%
def summarize(y_true, y_pred):
    weeks_true = np.split(y_true, 6, 1)
    weeks_pred = np.split(y_pred, 6, 1)
    matrices = []
    macro_f1s = []
    maes = []
    for y_true, y_pred in zip(weeks_true, weeks_pred):
        y_true = round_and_intify(y_true.flatten())
        y_pred = round_and_intify(y_pred.flatten())
        matrix = metrics.confusion_matrix(y_true, y_pred, normalize='true')
        matrices += [matrix]
        report = metrics.classification_report(y_true, y_pred, digits=3)
        r = re.compile('(?<=macro avg\s{6}\d.\d{3}\s{5}\d.\d{3}\s{5})\d.\d{3}')
        macro_f1s += [r.search(report).group(0)]
        maes += [f"{np.mean(abs(y_true - y_pred)):.3f}"]
    warnings.filterwarnings('ignore')
    labels = ["None", "D0", "D1", "D2", "D3", "D4"]
    plot_confusion_matrices(matrices, labels, macro_f1s, maes)

# %% [markdown]
# ``macro_f1()`` just returns the macro F1 score

# %%
def macro_f1(y_true, y_pred):
    weeks_true = np.split(y_true, 6, 1)
    weeks_pred = np.split(y_pred, 6, 1)
    macro_f1s = []
    for y_true, y_pred in zip(weeks_true, weeks_pred):
        y_true = round_and_intify(y_true.flatten())
        y_pred = round_and_intify(y_pred.flatten())
        report = metrics.classification_report(y_true, y_pred, digits=3)
        r = re.compile('(?<=macro avg\s{6}\d.\d{3}\s{5}\d.\d{3}\s{5})\d.\d{3}')
        macro_f1s += [r.search(report).group(0)]
    mf1 = np.mean([float(x) for x in macro_f1s])
    return mf1

# %% [markdown]
# ## Transforming with ROCKET
#
# Here, we transform our time series with some convolutional kernels using MiniROCKET.
#
# ROCKET produces ~10.000 values for each time series, not matter its length.
#
# The ``fit()`` function name is misleading, as ROCKET needs **no training at all**. It merely adjusts it for the multivariate dimensions.

# %%
import numpy as np
from sktime.transformations.panel.rocket import MiniRocketMultivariate

minirocket_multi = MiniRocketMultivariate()
minirocket_multi.fit(X_time_train)
# Out:
# MiniRocketMultivariate()

# %%
X_train_rocket = minirocket_multi.transform(X_time_train)
X_train_rocket
# Out:
#             0         1         2         3         4         5         6     \
# 0       0.142857  0.809524  0.047619  0.428571  1.000000  0.095238  0.666667
# 1       0.238095  1.000000  0.000000  0.619048  1.000000  0.047619  0.904762
# 2       0.142857  0.952381  0.142857  0.714286  1.000000  0.142857  0.904762
# 3       0.142857  0.904762  0.000000  0.761905  1.000000  0.047619  0.857143
# 4       0.285714  0.952381  0.000000  0.571429  1.000000  0.142857  0.761905
# ...          ...       ...       ...       ...       ...       ...       ...
# 103385  0.380952  0.571429  0.142857  0.476190  0.666667  0.333333  0.523810
# 103386  0.238095  0.761905  0.047619  0.523810  0.952381  0.142857  0.619048
# 103387  0.142857  0.857143  0.047619  0.666667  0.952381  0.142857  0.809524
# 103388  0.238095  0.714286  0.095238  0.428571  0.904762  0.142857  0.571429
# 103389  0.142857  0.857143  0.047619  0.809524  0.952381  0.142857  0.809524
#
# ...

# %% [markdown]
# As you can see, we now have ~10.000 features per time series.
#
# Finally, we concatenate the fixed-size data on soil quality etc. to the ROCKET features.

# %%
print(X_train_rocket.shape)
print(X_static_train.shape)

X_train_rocket = np.concatenate((X_train_rocket, X_static_train), axis=1)

print(X_train_rocket.shape)
# Out:
# (103390, 9996)
# (103390, 30)
# (103390, 10026)

# %% [markdown]
# ## Loading the validation data
#
# Here we load the validation data and flatten it or transform the time series data into ROCKET features, just like for the training data.
#
# Then, we concatenate the fixed-size data on soil quality etc. to the flattened and ROCKET features.

# %%
X_static_valid, X_time_valid, y_target_valid = loadXY("valid")
print("validation shape", X_time_valid.shape)
X_static_valid, X_time_valid = normalize(X_static_valid, X_time_valid)
# Out:
#   0%|          | 0/3108 [00:00<?, ?it/s]
# loaded 8748 samples
# validation shape (8748, 180, 21)
# ...
#   0%|          | 0/30 [00:00<?, ?it/s]

# %% [markdown]
# To create ``X_valid``, we are flattening out the time data, pretending there is no temporal component.

# %%
print(X_time_valid.shape)

X_valid = np.array(list(map(lambda x: x.flatten(), X_time_valid)))

print(X_valid.shape)
print(X_static_valid.shape)

X_valid = np.concatenate((X_valid, X_static_valid), axis=1)

print(X_valid.shape)
# Out:
# (8748, 180, 21)
# (8748, 3780)
# (8748, 30)
# (8748, 3810)

# %% [markdown]
# To create ``X_valid_rocket``, we are using the ROCKET features instead.

# %%
X_valid_rocket = minirocket_multi.transform(X_time_valid)

print(X_valid_rocket.shape)
print(X_static_valid.shape)

X_valid_rocket = np.concatenate((X_valid_rocket, X_static_valid), axis=1)

print(X_valid_rocket.shape)
# Out:
# (8748, 9996)
# (8748, 30)
# (8748, 10026)

# %% [markdown]
# ## Goal: perfect classification
#
# The following is a report that shows perfect classification of our samples. This is the ideal we want to achieve, just so you know what to look for.

# %%
summarize(y_target_valid, y_target_valid)

# %% [markdown]
# ## Random: always predict a random class
#
# Here we check what the results are for always predicting a random class between 0 and 5.

# %%
summarize(y_target_valid, np.random.randint(6, size=y_target_valid.shape))

# %% [markdown]
# ## Majority class: always predict 'no drought'
#
# Here we check what the results are for always predicting the majority class, which is 'no drought' (0).

# %%
summarize(y_target_valid, np.zeros_like(y_target_valid))

# %% [markdown]
# ## Random (stratified): predict a random class based on observed priors
#
# Here we check what the results are for always predicting a random class between 0 and 5, according to how often they appear.

# %%
total = len(y_target_train.flatten())
probs = []
print(f"{bold('Total')}:  {total}  (100%)")
for x, count in zip(np.unique(round_and_intify(y_target_train), return_counts=True)[0],
                    np.unique(round_and_intify(y_target_train), return_counts=True)[1]):
    print(f"    {bold(x)}:  {count:6}  ({count/total*100:.4f}%)")
    probs += [count/total]
# Out:
# Total:  620340  (100%)
#     0:  375565  (60.5418%)
#     1:  103965  (16.7594%)
#     2:   64910  (10.4636%)
#     3:   42728  (6.8878%)
#     4:   24262  (3.9111%)
#     5:    8910  (1.4363%)

# %%
stratified = np.random.choice(6, y_target_valid.shape, p=probs)
summarize(y_target_valid, stratified)

# %% [markdown]
# ## Continuity: repeat last observed drought category
#
# Here we simply take the drought category observed in time step 180 and repeat it six times. Multiplication with 1.2 approximates de-normalization.

# %%
summarize(y_target_valid, np.array(list(map(lambda x: [x*1.2]*6, X_time_valid[:,-1,18]))))

# %% [markdown]
# ## Ridge classification
#
# Here, we train a ridge classifier on the ROCKET features. We are using the ``MultiOutputClassifier`` wrapper, which means we are effectively training 6 classifiers independently.

# %%
from sklearn.multioutput import MultiOutputClassifier
from sklearn.linear_model import RidgeClassifier

tic = time.perf_counter()
classifier = MultiOutputClassifier(RidgeClassifier(alpha=0.5, normalize=True))
classifier.fit(X_train, round_and_intify(y_target_train))
# Out:
# MultiOutputClassifier(estimator=RidgeClassifier(alpha=0.5, normalize=True))

# %%
y_pred_valid = classifier.predict(X_valid)
summarize(y_target_valid, y_pred_valid)
toc = time.perf_counter()
duration = toc - tic
minutes = int(duration/60)
print(f"Elapsed time: {str(minutes) + ' minutes, ' if minutes else ''}{int(duration % 60)} seconds")
# Out:
# Elapsed time: 1 minutes, 9 seconds

# %%
tic = time.perf_counter()
classifier_rocket = MultiOutputClassifier(RidgeClassifier(alpha=0.5, normalize=True))
classifier_rocket.fit(X_train_rocket, round_and_intify(y_target_train))
y_pred_valid = classifier_rocket.predict(X_valid_rocket)
summarize(y_target_valid, y_pred_valid)
toc = time.perf_counter()
duration = toc - tic
minutes = int(duration/60)
print(f"Elapsed time: {str(minutes) + ' minutes, ' if minutes else ''}{int(duration % 60)} seconds")
# Out:
# Elapsed time: 5 minutes, 48 seconds

# %% [markdown]
# It becomes immediately visible that our results using ridge classification are already much better than any of the baselines established above. However, the confusion matrix shows a significant favoring of the no drought category and generally underestimates the higher drought categories.

# %% [markdown]
# ## Ridge regression
#
# Here, we don't train a ridge classifier, but a ridge regressor. The predictions then get rounded afterwards. We are using the ``MultiOutputRegressor`` wrapper, which means we are effectively training 6 regressors independently.

# %%
from sklearn.multioutput import MultiOutputRegressor
from sklearn.linear_model import Ridge

tic = time.perf_counter()
ridgeRegressor = MultiOutputRegressor(Ridge(alpha=0.1, normalize=True))
ridgeRegressor.fit(X_train, np.squeeze(y_target_train))
# Out:
# MultiOutputRegressor(estimator=Ridge(alpha=0.1, normalize=True))

# %%
y_pred_valid = ridgeRegressor.predict(X_valid)
summarize(y_target_valid, y_pred_valid)
toc = time.perf_counter()
duration = toc - tic
minutes = int(duration/60)
print(f"Elapsed time: {str(minutes) + ' minutes, ' if minutes else ''}{int(duration % 60)} seconds")
# Out:
# Elapsed time: 48 seconds

# %%
tic = time.perf_counter()
ridgeRegressor_rocket = MultiOutputRegressor(Ridge(alpha=0.1, normalize=True))
ridgeRegressor_rocket.fit(X_train_rocket, np.squeeze(y_target_train))
y_pred_valid = ridgeRegressor_rocket.predict(X_valid_rocket)
summarize(y_target_valid, y_pred_valid)
toc = time.perf_counter()
duration = toc - tic
minutes = int(duration/60)
print(f"Elapsed time: {str(minutes) + ' minutes, ' if minutes else ''}{int(duration % 60)} seconds")
# Out:
# Elapsed time: 4 minutes, 47 seconds

# %% [markdown]
# Including the ordinal information of the classes by training a regressor instead of a classifier did not just increase our F1 score, but also made our confusion matrix look a lot more symmetric along our diagonal.
#
# Since the improvement is so dramatic, we will be focusing exclusively on regression models from now on.

# %% [markdown]
# ## Lasso regression
#
# Lasso regression uses the L1 norm to regularize its model. This encourages sparsity more than L2.

# %%
from sklearn.linear_model import ElasticNet

tic = time.perf_counter()
lassoRegressor = MultiOutputRegressor(ElasticNet(alpha=0.1, normalize=True))
lassoRegressor.fit(X_train, np.squeeze(y_target_train))
# Out:
# MultiOutputRegressor(estimator=ElasticNet(alpha=0.1, normalize=True))

# %%
y_pred_valid = lassoRegressor.predict(X_valid)
summarize(y_target_valid, y_pred_valid)
toc = time.perf_counter()
duration = toc - tic
minutes = int(duration/60)
print(f"Elapsed time: {str(minutes) + ' minutes, ' if minutes else ''}{int(duration % 60)} seconds")
# Out:
# Elapsed time: 25 seconds

# %%
tic = time.perf_counter()
lassoRegressor_rocket = MultiOutputRegressor(ElasticNet(alpha=0.1, normalize=True))
lassoRegressor_rocket.fit(X_train_rocket, np.squeeze(y_target_train))
y_pred_valid = lassoRegressor_rocket.predict(X_valid_rocket)
summarize(y_target_valid, y_pred_valid)
toc = time.perf_counter()
duration = toc - tic
minutes = int(duration/60)
print(f"Elapsed time: {str(minutes) + ' minutes, ' if minutes else ''}{int(duration % 60)} seconds")
# Out:
# Elapsed time: 1 minutes, 11 seconds

# %% [markdown]
# ## Linear regression
#
# Here, we use a plain linear regressor without normalization. Again, the predictions get rounded afterwards and we are using the ``MultiOutputRegressor`` wrapper.

# %%
from sklearn.linear_model import LinearRegression

tic = time.perf_counter()
linearRegressor = MultiOutputRegressor(LinearRegression(normalize=True))
linearRegressor.fit(X_train, np.squeeze(y_target_train))
# Out:
# MultiOutputRegressor(estimator=LinearRegression(normalize=True))

# %%
y_pred_valid = linearRegressor.predict(X_valid)
summarize(y_target_valid, y_pred_valid)
toc = time.perf_counter()
duration = toc - tic
minutes = int(duration/60)
print(f"Elapsed time: {str(minutes) + ' minutes, ' if minutes else ''}{int(duration % 60)} seconds")
# Out:
# Elapsed time: 6 minutes, 13 seconds

# %%
tic = time.perf_counter()
linearRegressor_rocket = MultiOutputRegressor(LinearRegression(normalize=True))
linearRegressor_rocket.fit(X_train_rocket, np.squeeze(y_target_train))
y_pred_valid = linearRegressor_rocket.predict(X_valid_rocket)
summarize(y_target_valid, y_pred_valid)
toc = time.perf_counter()
duration = toc - tic
minutes = int(duration/60)
print(f"Elapsed time: {str(minutes) + ' minutes, ' if minutes else ''}{int(duration % 60)} seconds")
# Out:
# Elapsed time: 52 minutes, 14 seconds

# %% [markdown]
# As you can see, the results using linear regression are even better than for ridge regression.

# %% [markdown]
# ## Decision tree regression
#
# Here, we use a single decision tree as regression model. Again, the predictions get rounded afterwards and we are using the ``MultiOutputRegressor`` wrapper.

# %%
from sklearn.tree import DecisionTreeRegressor

tic = time.perf_counter()
treeRegressor = MultiOutputRegressor(DecisionTreeRegressor())
treeRegressor.fit(X_train, np.squeeze(y_target_train))
# Out:
# MultiOutputRegressor(estimator=DecisionTreeRegressor())

# %%
y_pred_valid = treeRegressor.predict(X_valid)
summarize(y_target_valid, y_pred_valid)
toc = time.perf_counter()
duration = toc - tic
minutes = int(duration/60)
print(f"Elapsed time: {str(minutes) + ' minutes, ' if minutes else ''}{int(duration % 60)} seconds")
# Out:
# Elapsed time: 180 minutes, 52 seconds

# %%
tic = time.perf_counter()
treeRegressor_rocket = MultiOutputRegressor(DecisionTreeRegressor())
treeRegressor_rocket.fit(X_train_rocket, np.squeeze(y_target_train))
y_pred_valid = treeRegressor_rocket.predict(X_valid_rocket)
summarize(y_target_valid, y_pred_valid)
toc = time.perf_counter()
duration = toc - tic
minutes = int(duration/60)
print(f"Elapsed time: {str(minutes) + ' minutes, ' if minutes else ''}{int(duration % 60)} seconds")
# Out:
# Elapsed time: 93 minutes, 19 seconds

# %% [markdown]
# ## Decision tree classifier
#
# Same as above, but with classification instead of regression.

# %%
from sklearn.tree import DecisionTreeClassifier

tic = time.perf_counter()
treeClassifier = MultiOutputClassifier(DecisionTreeClassifier())
treeClassifier.fit(X_train, round_and_intify(y_target_train))
# Out:
# MultiOutputClassifier(estimator=DecisionTreeClassifier())

# %%
y_pred_valid = treeClassifier.predict(X_valid)
summarize(y_target_valid, y_pred_valid)
toc = time.perf_counter()
duration = toc - tic
minutes = int(duration/60)
print(f"Elapsed time: {str(minutes) + ' minutes, ' if minutes else ''}{int(duration % 60)} seconds")
# Out:
# Elapsed time: 136 minutes, 8 seconds

# %%
tic = time.perf_counter()
treeClassifier_rocket = MultiOutputRegressor(DecisionTreeClassifier())
treeClassifier_rocket.fit(X_train_rocket, round_and_intify(y_target_train))
y_pred_valid = treeClassifier_rocket.predict(X_valid_rocket)
summarize(y_target_valid, y_pred_valid)
toc = time.perf_counter()
duration = toc - tic
minutes = int(duration/60)
print(f"Elapsed time: {str(minutes) + ' minutes, ' if minutes else ''}{int(duration % 60)} seconds")
# Out:
# Elapsed time: 61 minutes, 43 seconds

# %% [markdown]
# ## Ridge classification, chained
#
# To us it seems natural that a prediction for week 4 should not only be based on the 180 days in ``X``, but also our own predictions for week 1, 2 and 3. The ``ClassifierChain`` wrapper does this by training 6 classifiers that use ``X`` as well as all predictions by previous classifiers in the chain as input.

# %%
# from sklearn.multioutput import ClassifierChain

# tic = time.perf_counter()
# ridgeClassifierChain = ClassifierChain(RidgeClassifier(alpha=0.5, normalize=True))
# ridgeClassifierChain.fit(X_train, round_and_intify(y_target_train))

# %%
# y_pred_valid = ridgeClassifierChain.predict(X_valid)
# summarize(y_target_valid, y_pred_valid)
# toc = time.perf_counter()
# duration = toc - tic
# minutes = int(duration/60)
# print(f"Elapsed time: {str(minutes) + ' minutes, ' if minutes else ''}{int(duration % 60)} seconds")

# %% [markdown]
# ## Ridge regression, chained
#
# Just like the ``ClassifierChain``, the ``RegressorChain`` wrapper trains 6 models that use ``X`` as well as all predictions by previous models in the chain as input.

# %%
# from sklearn.multioutput import RegressorChain

# tic = time.perf_counter()
# ridgeRegressorChain = RegressorChain(Ridge(alpha=0.5, normalize=True))
# ridgeRegressorChain.fit(X_train, np.squeeze(y_target_train))

# %%
# y_pred_valid = ridgeRegressorChain.predict(X_valid)
# summarize(y_target_valid, y_pred_valid)
# toc = time.perf_counter()
# duration = toc - tic
# minutes = int(duration/60)
# print(f"Elapsed time: {str(minutes) + ' minutes, ' if minutes else ''}{int(duration % 60)} seconds")

# %% [markdown]
# ## Linear regression, chained
#
# The same chaining as above for linear regression.

# %%
# tic = time.perf_counter()
# linearRegressorChain = RegressorChain(LinearRegression(normalize=True))
# linearRegressorChain.fit(X_train, np.squeeze(y_target_train))

# %%
# y_pred_valid = linearRegressorChain.predict(X_valid)
# summarize(y_target_valid, y_pred_valid)
# toc = time.perf_counter()
# duration = toc - tic
# minutes = int(duration/60)
# print(f"Elapsed time: {str(minutes) + ' minutes, ' if minutes else ''}{int(duration % 60)} seconds")

# %% [markdown]
# ## Recursive feature elimination
#
# To determine which feature is how important we are recursively eliminating (sets of) features. Sadly, scikit-learn's inbuilt feature selection does not allow us to eliminate entire groups of features (e.g. all 180 precipitation values) at once, so we implement our own.

# %%
dims = len(X_time_train[0,0,:])
mf1s = []
dimension_hierarchy = []
outer_tic = time.perf_counter()
for i in range(dims):
    print(f"Training ridge regressor without dimension {i+1} of {dims}")
    tic = time.perf_counter()
    X_time_train_downsized = np.delete(X_time_train, dimension_hierarchy+[i], 2)
    X_train = np.array(list(map(lambda x: x.flatten(), X_time_train_downsized)))
    X_train = np.concatenate((X_train, X_static_train), axis=1)
    print(X_time_train_downsized.shape)
    ridgeRegressor = MultiOutputRegressor(Ridge(alpha=0.5, normalize=True))
    ridgeRegressor.fit(X_train, np.squeeze(y_target_train))
    X_time_valid_downsized = np.delete(X_time_valid, i, 2)
    X_valid = np.array(list(map(lambda x: x.flatten(), X_time_valid_downsized)))
    X_valid = np.concatenate((X_valid, X_static_valid), axis=1)
    y_pred_valid = ridgeRegressor.predict(X_valid)
    mf1s += [macro_f1(y_target_valid, y_pred_valid)]
    summarize(y_target_valid, y_pred_valid)
    toc = time.perf_counter()
    duration = toc - tic
    minutes = int(duration/60)
    print(f"Elapsed time: {str(minutes) + ' minutes, ' if minutes else ''}{int(duration % 60)} seconds\n")
print(mf1s)
outer_toc = time.perf_counter()
duration = outer_toc - outer_tic
minutes = int(duration/60)
print(f"Elapsed time for loop: {str(minutes) + ' minutes, ' if minutes else ''}{int(duration % 60)} seconds\n")
# Out:
# Training ridge regressor without dimension 1 of 21
# (103390, 180, 20)
# Elapsed time: 1 minutes, 0 seconds
#
# Training ridge regressor without dimension 2 of 21
# (103390, 180, 20)
# Elapsed time: 50 seconds
#
# Training ridge regressor without dimension 3 of 21
# (103390, 180, 20)
# Elapsed time: 50 seconds
#
# Training ridge regressor without dimension 4 of 21
# (103390, 180, 20)
# Elapsed time: 51 seconds
#
# Training ridge regressor without dimension 5 of 21
# (103390, 180, 20)
# Elapsed time: 49 seconds
#
# Training ridge regressor without dimension 6 of 21
# (103390, 180, 20)
# Elapsed time: 52 seconds
#
# Training ridge regressor without dimension 7 of 21
# (103390, 180, 20)
# Elapsed time: 58 seconds
#
# Training ridge regressor without dimension 8 of 21
# (103390, 180, 20)
# Elapsed time: 55 seconds
#
# Training ridge regressor without dimension 9 of 21
# (103390, 180, 20)
# Elapsed time: 52 seconds
#
# Training ridge regressor without dimension 10 of 21
# ...

# %%
dims = len(X_time_train[0,:,0])
mf1s = []
outer_tic = time.perf_counter()
for i in range(dims-1):
    print(f"Training ridge regressor without time steps 1 to {i+1} of {dims}")
    tic = time.perf_counter()
    X_time_train_downsized = np.delete(X_time_train, list(range(i)), 1)
    X_train = np.array(list(map(lambda x: x.flatten(), X_time_train_downsized)))
    X_train = np.concatenate((X_train, X_static_train), axis=1)
    print(X_time_train_downsized.shape)
    ridgeRegressor = MultiOutputRegressor(Ridge(alpha=0.5, normalize=True))
    ridgeRegressor.fit(X_train, np.squeeze(y_target_train))
    X_time_valid_downsized = np.delete(X_time_valid, i, 2)
    X_valid = np.array(list(map(lambda x: x.flatten(), X_time_valid_downsized)))
    X_valid = np.concatenate((X_valid, X_static_valid), axis=1)
    y_pred_valid = ridgeRegressor.predict(X_valid)
    mf1s += [macro_f1(y_target_valid, y_pred_valid)]
    summarize(y_target_valid, y_pred_valid)
    toc = time.perf_counter()
    duration = toc - tic
    minutes = int(duration/60)
    print(f"Elapsed time: {str(minutes) + ' minutes, ' if minutes else ''}{int(duration % 60)} seconds\n")
print(mf1s)
outer_toc = time.perf_counter()
duration = outer_toc - outer_tic
minutes = int(duration/60)
print(f"Elapsed time for loop: {str(minutes) + ' minutes, ' if minutes else ''}{int(duration % 60)} seconds\n")
